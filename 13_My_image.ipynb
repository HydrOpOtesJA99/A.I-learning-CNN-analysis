# %% [markdown]
# <a href="https://colab.research.google.com/github/HydrOpOtesJA99/A.I-learning-CNN-analysis/blob/main/13_My_image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 13_My_image

# %%
# !wget -q https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/notMNIST_small.tar.gz
# !tar -xzf notMNIST_small.tar.gz

# %% [markdown]
# > 지금 사용할 dataset=NotMNIST: A~J 10개의 알파벳 분류

# %% [markdown]
# ![Myimage_1.png](data:image/png;base64,...)

# %% [markdown]
# *   './notMNIST_small?*/*.png': notMNIST_small 폴더 아래의 확장자가 .png인 파일들만 읽어 들인다.
#
# *   (18724, 28, 28): 28,28의 흑백이미지, 만약 컬러이미지였다면 28,28,3 3차원으로 이미지를 읽을 것이다.
#
# *   개별 이미지들의 size가 제각각일 경우에는 코드로 통일시킬 수도 있지만,
#
# *   포토샵등 이미지 편집 도구들을 이용해 resizing 하는 법도 있다.
