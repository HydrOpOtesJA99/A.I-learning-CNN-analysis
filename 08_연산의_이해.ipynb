# %% [markdown]
# <a href="https://colab.research.google.com/github/HydrOpOtesJA99/A.I-learning-CNN-analysis/blob/main/08_%EC%97%B0%EC%82%B0%EC%9D%98_%EC%9D%B4%ED%95%B4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 8_연산의_이해

# %% [markdown]
# ## 연산 원리

# %% [markdown]
# > 아래 방법을 사용하지 않는 딥러닝이 없음

# %% [markdown]
# ![연산의_이해.png](data:image/png;base64,...)

# %% [markdown]
# 1.   Convolution 연산을 위해 필터를 inputdata 좌측 상단부터 곂쳐준다
#
# 2.   같은 위치의 숫자끼리 곱하고 그 결과를 모두 합쳐 값을 도출한다
#
# 3.   도출된 값을 특징맵의 좌측상단부터 적는다
#
# 4.   필터를 욺직여가며 특징맵을 채운다

# %% [markdown]
# ## 필터가 움직이는 순서

# %% [markdown]
# ![연산의_이해_1.png](data:image/png;base64,...)

# %% [markdown]
# ![연산의_이해_2.png](data:image/png;base64,...)

# %% [markdown]
# ...................... 반복

# %% [markdown]
# ![연산의_이해_3.png](data:image/png;base64,...)

# %% [markdown]
# ![연산의_이해_4.png](data:image/png;base64,...)

# %% [markdown]
# ...................... 최종적으로 아래와 같이 만들어진다.

# %% [markdown]
# ![연산의_이해_5.png](data:image/png;base64,...)
